# %% [markdown]
# Stock Symbol Dataset
#
# Kelly Simmons
#
# 2/21/2023

# %% [markdown]
# 1. Load
#
# Symbols_valid_meta.csv file has been stored in Repo and loaded to DataFrame.

# %%
import pandas as pd

# %%
df = pd.read_csv('symbols_valid_meta.csv', index_col=0)

# %% [markdown]
# 2. First Twenty Rows

# %%
df.head(20)
# Out:
#               Symbol                                      Security Name  \
# Nasdaq Traded
# Y                  A            Agilent Technologies, Inc. Common Stock
# Y                 AA                    Alcoa Corporation Common Stock
# Y               AAAU                       Perth Mint Physical Gold ETF
# Y               AACG  ATA Creativity Global - American Depositary Sh...
# Y               AADR                AdvisorShares Dorsey Wright ADR ETF
# Y                AAL       American Airlines Group, Inc. - Common Stock
# Y               AAMC               Altisource Asset Management Corp Com
# Y               AAME       Atlantic American Corporation - Common Stock
# Y                AAN                         Aaron's, Inc. Common Stock
# Y               AAOI       Applied Optoelectronics, Inc. - Common Stock
# Y               AAON                          AAON, Inc. - Common Stock
# Y                AAP  Advance Auto Parts Inc Advance Auto Parts Inc W/I
# ...

# %% [markdown]
# Last Twenty Rows

# %%
df.tail(20)
# Out:
#               Symbol                                      Security Name  \
# Nasdaq Traded
# Y               ZLAB       Zai Lab Limited - American Depositary Shares
# Y                 ZM  Zoom Video Communications, Inc. - Class A Comm...
# Y               ZMLP        Direxion Zacks MLP High Income Index Shares
# Y                 ZN                           Zion Oil  - Common Stock
# Y               ZNGA                  Zynga Inc. - Class A Common Stock
# Y                ZNH  China Southern Airlines Company Limited Common...
# Y                ZOM       Zomedica Pharmaceuticals Corp. Common Shares
# Y               ZROZ  PIMCO 25  Year Zero Coupon U.S. Treasury Index...
# Y                 ZS                       Zscaler, Inc. - Common Stock
# Y               ZSAN           Zosano Pharma Corporation - Common Stock
# Y                ZSL                        ProShares UltraShort Silver
# Y                ZTO  ZTO Express (Cayman) Inc. American Depositary ...
# ...

# %% [markdown]
# 3. Describe

# %%
df.describe()
# Out:
#        Round Lot Size
# count     8049.000000
# mean        99.942974
# std          2.289194
# min          1.000000
# 25%        100.000000
# 50%        100.000000
# 75%        100.000000
# max        100.000000

# %% [markdown]
# 4. Series

# %%
nasdaq_traded = ['Yes', 'No']
listing_exchange = ['Q', 'P', 'N', 'A']
financial_status = ['N', 'NaN', 'D']
my_series = pd.Series([nasdaq_traded, listing_exchange, financial_status])

# %%
print(my_series)
# Out:
# 0       [Yes, No]
# 1    [Q, P, N, A]
# 2     [N, NaN, D]
# dtype: object

# %%
unique_values = my_series.unique

# %%
print(unique_values)
# Out:
# <bound method Series.unique of 0       [Yes, No]
# 1    [Q, P, N, A]
# 2     [N, NaN, D]
# dtype: object>

# %% [markdown]
# Stocks Sorted by Financial Status.

# %%
symbols_valid_meta = pd.read_csv("symbols_valid_meta.csv")

# %%
sorted_stocks = symbols_valid_meta.sort_values(by="Financial Status", ascending=False)
print(sorted_stocks)
# Out:
#      Nasdaq Traded Symbol                                      Security Name  \
# 3                Y   AACG  ATA Creativity Global - American Depositary Sh...
# 5306             Y   OPCH            Option Care Health, Inc. - Common Stock
# 5286             Y     ON        ON Semiconductor Corporation - Common Stock
# 5287             Y    ONB                Old National Bancorp - Common Stock
# 5288             Y   ONCS        OncoSec Medical Incorporated - Common Stock
# ...            ...    ...                                                ...
# 8040             Y    ZTO  ZTO Express (Cayman) Inc. American Depositary ...
# 8041             Y    ZTR                      Virtus Total Return Fund Inc.
# 8042             Y    ZTS                   Zoetis Inc. Class A Common Stock
# 8044             Y    ZUO                   Zuora, Inc. Class A Common Stock
# 8046             Y   ZYME                       Zymeworks Inc. Common Shares
#
# ...
